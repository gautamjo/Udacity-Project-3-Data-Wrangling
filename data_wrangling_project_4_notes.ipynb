# %%
# importing modules needed for this section
import xml.etree.cElementTree as ET 
from collections import defaultdict
import re 
import os
import operator
from prettytable import PrettyTable as PT
from pprint import pprint

# %%
bigger_sample_file = "new_delhi_sample.osm" # sample file taken from the orignal

# %%
# checking the number tags named "tag" in the the sample file.
count= 0
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        count+=1
print(count)
# Out:
# 82169

# %%
# Now counting the number of all the tags in the sample file
def count_tags(file):
    tags = {} # creating a dictionary for tag names and their count 
    for event, elem in ET.iterparse(file):
        tags[elem.tag] = tags.get(elem.tag, 0) + 1
    print(tags)
count_tags(bigger_sample_file)
# Out:
# {'tag': 82169, 'node': 340762, 'nd': 421392, 'way': 69426, 'member': 2795, 'relation': 619, 'osm': 1}

# %%
# I am going to check attributes for all top level tags
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.attrib:
                print(tag)
        break
# Out:
# changeset
# id
# lat
# lon
# timestamp
# uid
# user
# version

# %%
# checking for unique users in the dataset
unique_usr = set()
for event, elem in ET.iterparse(bigger_sample_file):
    if "uid" in elem.attrib:
        unique_usr.add(elem.attrib["uid"])
print(len(unique_usr))
# Out:
# 824

# %%
# elem.attrib is dict object
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        print(type(elem.attrib))
        break
# Out:
# <class 'dict'>

# %%
# Next I want to check what does the tag elements contain
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        print(elem.attrib)
        break
# Out:
# {'k': 'admin_level', 'v': '2'}

# %%
# Now I know that element "tag" consists attributes "k" and "v". 
# I am going to explore these attributes further.
# I am interested in addr:street and addr:postcode. 
# Lets count how many times these occur in the dataset.
count = 0
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        attrib = elem.attrib["k"]
        if attrib == "addr:street" or attrib == "addr:postcode":
            count += 1
            print(count ,attrib)
# This sample data contains 39 entries with street addresses and postal codes
# Out:
# 1 addr:street
# 2 addr:street
# 3 addr:postcode
# 4 addr:street
# 5 addr:postcode
# 6 addr:street
# 7 addr:street
# 8 addr:street
# 9 addr:street
# 10 addr:street
# 11 addr:street
# 12 addr:postcode
# 13 addr:street
# 14 addr:street
# 15 addr:street
# 16 addr:postcode
# 17 addr:street
# 18 addr:postcode
# 19 addr:street
# 20 addr:postcode
# 21 addr:street
# 22 addr:postcode
# 23 addr:street
# 24 addr:postcode
# 25 addr:street
# 26 addr:street
# 27 addr:street
# 28 addr:street
# 29 addr:street
# 30 addr:street
# 31 addr:street
# 32 addr:street
# 33 addr:street
# 34 addr:street
# 35 addr:street
# 36 addr:street
# 37 addr:street
# 38 addr:street
# 39 addr:street
# 40 addr:postcode
# 41 addr:street
# 42 addr:postcode
# 43 addr:street
# 44 addr:postcode
# 45 addr:street
# 46 addr:postcode
# 47 addr:street
# 48 addr:postcode
# 49 addr:street
# 50 addr:postcode
# 51 addr:street
# 52 addr:postcode
# 53 addr:street
# 54 addr:postcode
# 55 addr:street
# 56 addr:postcode
# 57 addr:street
# 58 addr:postcode
# 59 addr:street
# 60 addr:postcode
# 61 addr:street
# 62 addr:postcode
# 63 addr:street
# 64 addr:postcode
# 65 addr:postcode
# 66 addr:street
# 67 addr:street
# 68 addr:street
# 69 addr:street
# 70 addr:street
# 71 addr:postcode
# 72 addr:street
# 73 addr:postcode
# 74 addr:street
# 75 addr:postcode
# 76 addr:street
# 77 addr:postcode
# 78 addr:street
# 79 addr:postcode
# 80 addr:street
# 81 addr:street
# 82 addr:postcode
# 83 addr:street
# 84 addr:street
# 85 addr:postcode
# 86 addr:street
# 87 addr:postcode
# 88 addr:street
# 89 addr:street
# 90 addr:postcode
# 91 addr:postcode
# 92 addr:postcode
# 93 addr:street
# 94 addr:street
# 95 addr:postcode
# 96 addr:street
# 97 addr:street
# 98 addr:postcode
# 99 addr:postcode
# 100 addr:street
# 101 addr:postcode
# 102 addr:street
# 103 addr:postcode
# 104 addr:postcode
# 105 addr:street
# 106 addr:postcode
# 107 addr:street
# 108 addr:postcode
# 109 addr:street
# 110 addr:street
# 111 addr:postcode
# 112 addr:street
# 113 addr:street
# 114 addr:postcode
# 115 addr:street
# 116 addr:street
# 117 addr:street
# 118 addr:postcode
# 119 addr:postcode
# 120 addr:street
# 121 addr:postcode
# 122 addr:street
# 123 addr:postcode
# 124 addr:street
# 125 addr:postcode
# 126 addr:street
# 127 addr:postcode
# 128 addr:street
# 129 addr:postcode
# 130 addr:street
# 131 addr:postcode
# 132 addr:street
# 133 addr:postcode
# 134 addr:street
# 135 addr:street
# 136 addr:postcode
# 137 addr:postcode
# 138 addr:postcode
# 139 addr:postcode
# 140 addr:street
# 141 addr:postcode
# 142 addr:street
# 143 addr:postcode
# 144 addr:street
# 145 addr:postcode
# 146 addr:street
# 147 addr:postcode
# 148 addr:street
# 149 addr:street
# 150 addr:postcode
# 151 addr:street
# 152 addr:postcode
# 153 addr:postcode
# 154 addr:street
# 155 addr:street
# 156 addr:postcode
# 157 addr:street
# 158 addr:postcode
# 159 addr:postcode
# 160 addr:street
# 161 addr:postcode
# 162 addr:street
# 163 addr:postcode
# 164 addr:street
# 165 addr:postcode
# 166 addr:postcode
# 167 addr:street
# 168 addr:postcode
# 169 addr:street
# 170 addr:postcode
# 171 addr:street
# 172 addr:postcode
# 173 addr:postcode
# 174 addr:postcode
# 175 addr:street
# 176 addr:postcode
# 177 addr:street
# 178 addr:postcode
# 179 addr:street
# 180 addr:postcode
# 181 addr:street
# 182 addr:postcode
# 183 addr:street
# 184 addr:postcode
# 185 addr:street
# 186 addr:postcode
# 187 addr:postcode
# 188 addr:street
# 189 addr:street
# 190 addr:street
# 191 addr:postcode
# 192 addr:street
# 193 addr:postcode
# 194 addr:postcode
# 195 addr:street
# 196 addr:postcode
# 197 addr:postcode
# 198 addr:postcode
# 199 addr:postcode
# 200 addr:street
# 201 addr:postcode
# 202 addr:street
# 203 addr:street
# 204 addr:postcode
# 205 addr:street
# 206 addr:postcode
# 207 addr:street
# 208 addr:street
# 209 addr:postcode
# 210 addr:street
# 211 addr:street
# 212 addr:postcode
# 213 addr:postcode
# 214 addr:street
# 215 addr:postcode
# 216 addr:street
# 217 addr:street
# 218 addr:street
# 219 addr:postcode
# 220 addr:postcode
# 221 addr:street
# 222 addr:street
# 223 addr:postcode
# 224 addr:street
# 225 addr:postcode
# 226 addr:postcode
# 227 addr:street
# 228 addr:postcode
# 229 addr:street
# 230 addr:postcode
# 231 addr:street
# 232 addr:postcode
# 233 addr:street
# 234 addr:postcode
# 235 addr:street
# 236 addr:postcode
# 237 addr:street
# 238 addr:postcode
# 239 addr:street
# 240 addr:postcode
# 241 addr:street
# 242 addr:postcode
# 243 addr:street
# 244 addr:postcode
# 245 addr:street
# 246 addr:postcode
# 247 addr:street
# 248 addr:postcode
# 249 addr:street
# 250 addr:postcode
# 251 addr:street
# 252 addr:postcode
# 253 addr:street
# 254 addr:postcode
# 255 addr:street
# 256 addr:postcode
# 257 addr:street
# 258 addr:postcode
# 259 addr:street
# 260 addr:postcode
# 261 addr:street
# 262 addr:postcode
# 263 addr:street
# 264 addr:postcode
# 265 addr:street
# 266 addr:postcode
# 267 addr:street
# 268 addr:postcode
# 269 addr:street
# 270 addr:postcode
# 271 addr:street
# 272 addr:postcode
# 273 addr:street
# 274 addr:postcode
# 275 addr:street
# 276 addr:postcode
# 277 addr:street
# 278 addr:postcode
# 279 addr:street
# 280 addr:postcode
# 281 addr:street
# 282 addr:postcode
# 283 addr:street
# 284 addr:postcode
# 285 addr:street
# 286 addr:postcode
# 287 addr:street
# 288 addr:postcode
# 289 addr:street
# 290 addr:postcode
# 291 addr:street
# 292 addr:postcode
# 293 addr:street
# 294 addr:postcode
# 295 addr:street
# 296 addr:postcode
# 297 addr:street
# 298 addr:postcode
# 299 addr:street
# 300 addr:postcode
# 301 addr:street
# 302 addr:postcode
# 303 addr:street
# 304 addr:postcode
# 305 addr:street
# 306 addr:postcode
# 307 addr:street
# 308 addr:postcode
# 309 addr:street
# 310 addr:postcode
# 311 addr:street
# 312 addr:postcode
# 313 addr:street
# 314 addr:postcode
# 315 addr:street
# 316 addr:postcode
# 317 addr:street
# 318 addr:postcode
# 319 addr:street
# 320 addr:postcode
# 321 addr:street
# 322 addr:postcode
# 323 addr:street
# 324 addr:postcode
# 325 addr:street
# 326 addr:postcode
# 327 addr:street
# 328 addr:postcode
# 329 addr:street
# 330 addr:postcode
# 331 addr:street
# 332 addr:postcode
# 333 addr:street
# 334 addr:postcode
# 335 addr:street
# 336 addr:postcode
# 337 addr:street
# 338 addr:postcode
# 339 addr:street
# 340 addr:postcode
# 341 addr:street
# 342 addr:postcode
# 343 addr:street
# 344 addr:street
# 345 addr:postcode
# 346 addr:postcode
# 347 addr:street
# 348 addr:postcode
# 349 addr:street
# 350 addr:postcode
# 351 addr:street
# 352 addr:postcode
# 353 addr:street
# 354 addr:postcode
# 355 addr:street
# 356 addr:street
# 357 addr:postcode
# 358 addr:street
# 359 addr:postcode

# %%
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            print(tag.attrib["k"])
            break
# Out:
# admin_level
# source
# source
# source
# source
# highway
# atm
# created_by
# name
# highway
# highway
# name
# created_by
# created_by
# created_by
# created_by
# created_by
# created_by
# highway
# barrier
# created_by
# created_by
# created_by
# highway
# name
# highway
# amenity
# highway
# amenity
# name
# addr:street
# name
# highway
# name
# amenity
# name
# ref
# amenity
# name
# highway
# highway
# highway
# name
# ref
# name
# name
# highway
# highway
# amenity
# highway
# name
# name
# amenity
# highway
# name
# name
# highway
# highway
# highway
# amenity
# highway
# shop
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# highway
# name
# name
# highway
# traffic_calming
# highway
# barrier
# name
# power
# name
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# name
# name
# highway
# highway
# amenity
# name
# shop
# name
# name
# power
# power
# name
# amenity
# traffic_calming
# barrier
# power
# highway
# name
# power
# highway
# highway
# name
# name
# name
# barrier
# amenity
# name
# shop
# highway
# amenity
# name
# name
# amenity
# highway
# highway
# name
# name
# name
# addr:street
# addr:street
# addr:street
# addr:street
# addr:street
# foot
# addr:city
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:street
# addr:city
# name
# power
# amenity
# power
# name
# amenity
# power
# addr:street
# addr:city
# addr:city
# addr:city
# addr:city
# name
# name
# name
# name
# name
# natural
# natural
# natural
# name
# name
# ref
# sport
# highway
# name
# railway
# power
# entrance
# entrance
# name
# name
# addr:city
# tourism
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# name
# addr:city
# addr:city
# addr:city
# addr:city
# name
# highway
# amenity
# amenity
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# amenity
# name
# name
# name
# name
# shop
# name
# addr:housenumber
# power
# barrier
# power
# name
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# addr:city
# name
# tourism
# amenity
# name
# name
# name
# power
# power
# power
# power
# name
# power
# power
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# highway
# highway
# highway
# power
# power
# power
# power
# power
# power
# highway
# power
# power
# power
# highway
# power
# highway
# power
# highway
# power
# power
# power
# power
# power
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# highway
# highway
# highway
# railway
# railway
# railway
# railway
# railway
# railway
# amenity
# place
# name
# name
# railway
# name
# highway
# highway
# highway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# power
# power
# name
# power
# power
# power
# power
# power
# power
# name
# amenity
# amenity
# name
# ref
# amenity
# name
# name
# name
# highway
# name
# name
# name
# ref
# name
# name
# highway
# name
# name
# name
# name
# name
# name
# name
# name
# name
# ref
# foot
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# addr:city
# addr:city
# addr:city
# name
# power
# power
# power
# power
# power
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# foot
# power
# power
# power
# railway
# railway
# railway
# foot
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# shop
# leisure
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# name
# addr:city
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# fee
# name
# addr:city
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# man_made
# man_made
# name
# name
# highway
# name
# name
# barrier
# addr:housenumber
# addr:housenumber
# addr:housenumber
# barrier
# name
# ref
# name
# sport
# name
# foot
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# power
# power
# power
# power
# power
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# addr:housename
# addr:housename
# addr:housename
# addr:housename
# name
# name
# name
# name
# name
# power
# power
# power
# power
# name
# name
# highway
# name
# amenity
# name
# name
# building
# man_made
# barrier
# name
# name
# name
# name
# name
# name
# man_made
# man_made
# railway
# railway
# addr:housename
# amenity
# natural
# name
# man_made
# addr:housename
# man_made
# name
# name
# name
# name
# railway
# horse
# name
# name
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# highway
# name
# name
# amenity
# shop
# amenity
# shop
# amenity
# name
# name
# name
# shop
# amenity
# shop
# craft
# amenity
# shop
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# natural
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# power
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# man_made
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# highway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# power
# power
# power
# power
# man_made
# power
# railway
# railway
# power
# power
# man_made
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# railway
# name
# power
# amenity
# power
# name
# power
# railway
# power
# railway
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# name
# railway
# railway
# railway
# railway
# railway
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# railway
# name
# name
# highway
# name
# highway
# name
# name
# name
# ref
# ref
# ref
# ref
# ref
# power
# power
# power
# power
# power
# name
# name
# amenity
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# power
# power
# power
# power
# power
# name
# power
# power
# power
# power
# power
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# highway
# power
# railway
# man_made
# man_made
# man_made
# man_made
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# foot
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# power
# highway
# amenity
# highway
# amenity
# name
# name
# name
# barrier
# name
# name
# name
# ref
# natural
# natural
# natural
# natural
# natural
# name
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:postcode
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# power
# power
# power
# name
# name
# railway
# fixme
# name
# power
# power
# power
# power
# power
# power
# name
# name
# name
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# power
# name
# name
# historic
# name
# building
# name
# name
# amenity
# tourism
# amenity
# emergency
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# barrier
# fee
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# power
# power
# level
# name
# name
# level
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# barrier
# name
# amenity
# sport
# name
# name
# name
# name
# name
# power
# power
# power
# man_made
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# name
# name
# name
# name
# name
# name
# name
# name
# name
# place
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# barrier
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# amenity
# name
# name
# name
# name
# name
# name
# name
# name
# man_made
# name
# name
# name
# power
# power
# power
# name
# name
# name
# name
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# amenity
# name
# name
# name
# name
# name
# name
# name
# addr:housenumber
# addr:housenumber
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# barrier
# barrier
# power
# power
# power
# power
# power
# addr:housenumber
# addr:housenumber
# addr:housenumber
# name
# name
# name
# name
# historic
# name
# historic
# name
# name
# name
# atm
# name
# name
# power
# name
# name
# name
# construction
# name
# name
# name
# name
# name
# construction
# shop
# construction
# name
# name
# name
# name
# name
# name
# name
# highway
# highway
# name
# name
# name
# name
# name
# name
# name
# amenity
# name
# name
# name
# name
# name
# name
# name
# name
# name
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# amenity
# name
# name
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# railway
# railway
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# power
# fee
# addr:city
# name
# barrier
# shop
# railway
# name
# name
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# name
# fee
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# entrance
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# highway
# railway
# source
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# amenity
# power
# natural
# natural
# natural
# name
# name
# name
# name
# amenity
# amenity
# name
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# highway
# name
# name
# name
# barrier
# name
# name
# name
# name
# name
# ref
# name
# name
# name
# name
# name
# name
# name
# foot
# name
# addr:city
# name
# name
# ele
# name
# addr:city
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# shop
# power
# power
# power
# power
# power
# power
# power
# shop
# shop
# shop
# shop
# shop
# power
# power
# name
# power
# power
# power
# power
# power
# amenity
# name
# name
# name
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# name
# name
# name
# name
# shop
# power
# power
# addr:housenumber
# addr:housenumber
# name
# name
# railway
# highway
# highway
# name
# highway
# man_made
# highway
# man_made
# man_made
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# network
# network
# network
# railway
# name
# name
# name
# power
# power
# power
# power
# power
# name
# name
# name
# name
# name
# power
# power
# power
# power
# power
# power
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# place
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# natural
# natural
# natural
# natural
# natural
# natural
# name
# highway
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# name
# name
# shop
# name
# name
# name
# name
# name
# amenity
# addr:block_number
# building
# building
# name
# building
# amenity
# amenity
# highway
# name
# name
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# noexit
# name
# addr:city
# highway
# name
# name
# amenity
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# leisure
# name
# name
# name
# amenity
# name
# highway
# highway
# name
# power
# power
# power
# highway
# name
# name
# power
# power
# power
# name
# foot
# amenity
# name
# barrier
# power
# natural
# natural
# name
# name:ur
# power
# power
# power
# power
# power
# power
# power
# power
# name
# name
# bench
# name
# name
# name
# shop
# atm
# name
# name
# name
# barrier
# name
# name
# amenity
# name
# amenity
# ref
# name
# ref
# ref
# ref
# name
# name
# amenity
# shop
# amenity
# name
# name
# shop
# shop
# amenity
# name
# name
# bench
# amenity
# amenity
# craft
# amenity
# amenity
# name
# name
# name
# name
# name
# name
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# name
# name:en
# amenity
# power
# power
# power
# power
# power
# amenity
# name
# name
# name
# amenity
# amenity
# natural
# barrier
# amenity
# name
# amenity
# name
# name
# tourism
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# amenity
# name
# generator:method
# generator:method
# power
# power
# power
# name
# leisure
# name
# amenity
# name
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# power
# name
# name
# amenity
# name
# name
# name
# amenity
# name
# amenity
# railway
# name
# amenity
# amenity
# amenity
# name
# addr:housenumber
# addr:postcode
# tourism
# natural
# natural
# natural
# natural
# highway
# highway
# highway
# amenity
# natural
# natural
# highway
# highway
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# addr:housenumber
# amenity
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# name
# amenity
# amenity
# barrier
# name:ar
# addr:postcode
# name:en
# amenity
# amenity
# amenity
# amenity
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# power
# junction
# amenity
# type
# name
# name
# highway
# name
# name
# name
# oneway
# oneway
# highway
# oneway
# oneway
# highway
# highway
# name
# boundary
# access
# access
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# name
# name
# oneway
# name
# name
# name
# highway
# name
# name
# name
# name
# highway
# name
# highway
# highway
# oneway
# oneway
# highway
# highway
# name
# highway
# landuse
# leisure
# highway
# leisure
# highway
# highway
# highway
# leisure
# highway
# is_in
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# lanes
# oneway
# name
# name
# lanes
# highway
# lanes
# highway
# oneway
# lanes
# oneway
# name
# oneway
# ref
# ref
# ref
# access
# highway
# name
# highway
# highway
# highway
# oneway
# highway
# highway
# name
# ref
# name
# highway
# highway
# name
# highway
# name
# oneway
# ref
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# ref
# ref
# highway
# layer
# highway
# highway
# highway
# highway
# name
# power
# highway
# name
# oneway
# highway
# source
# name
# name
# name
# highway
# oneway
# layer
# ref
# landuse
# highway
# waterway
# highway
# name
# name
# highway
# name
# highway
# access
# aeroway
# landuse
# highway
# oneway
# oneway
# oneway
# alt_name
# natural
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# lanes
# waterway
# waterway
# power
# name
# highway
# layer
# waterway
# highway
# oneway
# name
# waterway
# natural
# waterway
# waterway
# oneway
# waterway
# waterway
# highway
# highway
# highway
# waterway
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# name
# name
# name
# highway
# highway
# highway
# highway
# name
# highway
# highway
# name
# highway
# building
# highway
# source
# name
# highway
# oneway
# oneway
# oneway
# oneway
# oneway
# source
# highway
# width
# ref
# name
# highway
# name
# highway
# addr:interpolation
# width
# addr:interpolation
# leisure
# highway
# highway
# source
# width
# highway
# highway
# highway
# highway
# name
# addr:interpolation
# addr:interpolation
# ref
# ref
# highway
# oneway
# addr:interpolation
# highway
# highway
# highway
# highway
# highway
# highway
# name
# name
# highway
# highway
# highway
# access
# name
# name
# name
# name
# source
# highway
# natural
# highway
# building
# area
# highway
# landuse
# oneway
# name
# name
# amenity
# name
# name
# highway
# oneway
# access
# name
# usage
# source
# gauge
# name
# name
# highway
# highway
# highway
# foot
# highway
# highway
# layer
# name
# highway
# name
# ref
# gauge
# highway
# highway
# highway
# highway
# building
# building
# highway
# highway
# highway
# addr:interpolation
# addr:interpolation
# highway
# addr:interpolation
# addr:interpolation
# addr:interpolation
# name
# landuse
# building
# oneway
# addr:interpolation
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# name
# lanes
# name
# ref
# source
# source
# source
# source
# layer
# landuse
# source
# amenity
# width
# width
# addr:inclusion
# addr:inclusion
# building
# name
# name
# highway
# landuse
# landuse
# highway
# highway
# highway
# highway
# layer
# name
# highway
# highway
# name
# highway
# name
# name
# name
# highway
# highway
# oneway
# addr:interpolation
# name
# addr:interpolation
# highway
# amenity
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# oneway
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# alt_name
# layer
# layer
# highway
# alt_name
# highway
# layer
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# railway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# name
# power
# power
# power
# building
# highway
# power
# oneway
# oneway
# alt_name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# power
# layer
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# oneway
# oneway
# highway
# name
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# name
# highway
# highway
# oneway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# oneway
# oneway
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# name
# highway
# foot
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# highway
# leisure
# highway
# width
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# name
# oneway
# railway
# oneway
# name
# name
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# sport
# oneway
# highway
# highway
# highway
# leisure
# sport
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# lanes
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# name
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# highway
# leisure
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# oneway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# layer
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# oneway
# highway
# leisure
# highway
# highway
# leisure
# highway
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# oneway
# highway
# name
# highway
# highway
# layer
# oneway
# oneway
# highway
# highway
# landuse
# oneway
# oneway
# highway
# oneway
# oneway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# oneway
# highway
# leisure
# highway
# landuse
# highway
# power
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# oneway
# oneway
# highway
# highway
# layer
# highway
# building
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# is_in
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# waterway
# layer
# highway
# highway
# oneway
# highway
# highway
# highway
# oneway
# oneway
# oneway
# highway
# highway
# highway
# highway
# is_in
# highway
# highway
# building
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# layer
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# leisure
# highway
# highway
# highway
# building
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# leisure
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# highway
# highway
# highway
# name
# oneway
# oneway
# ref
# highway
# oneway
# layer
# highway
# oneway
# leisure
# highway
# highway
# highway
# waterway
# amenity
# layer
# oneway
# layer
# highway
# barrier
# oneway
# oneway
# highway
# amenity
# leisure
# highway
# oneway
# oneway
# highway
# highway
# leisure
# highway
# amenity
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# leisure
# leisure
# layer
# highway
# highway
# leisure
# highway
# highway
# highway
# layer
# highway
# highway
# highway
# gauge
# power
# oneway
# oneway
# gauge
# oneway
# railway
# railway
# usage
# railway
# name
# gauge
# oneway
# ref
# oneway
# oneway
# ref
# oneway
# bridge
# oneway
# name
# name
# name
# name
# highway
# oneway
# highway
# name
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# highway
# highway
# highway
# gauge
# highway
# name
# gauge
# highway
# gauge
# highway
# oneway
# oneway
# oneway
# oneway
# layer
# ref
# waterway
# oneway
# name
# name
# oneway
# oneway
# name
# name
# highway
# highway
# highway
# highway
# highway
# power
# highway
# highway
# highway
# oneway
# leisure
# oneway
# name
# layer
# oneway
# highway
# gauge
# highway
# highway
# highway
# name
# oneway
# barrier
# oneway
# oneway
# oneway
# oneway
# gauge
# name
# highway
# oneway
# highway
# gauge
# gauge
# gauge
# oneway
# name
# name
# name
# gauge
# alt_name
# oneway
# name
# name
# gauge
# gauge
# gauge
# gauge
# oneway
# layer
# oneway
# oneway
# gauge
# name
# area
# oneway
# lanes
# oneway
# name
# layer
# layer
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# barrier
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# highway
# highway
# highway
# amenity
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# highway
# ref
# highway
# name
# highway
# highway
# highway
# landuse
# gauge
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# name
# name
# leisure
# highway
# highway
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# layer
# leisure
# gauge
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# leisure
# leisure
# highway
# leisure
# highway
# highway
# leisure
# highway
# landuse
# highway
# highway
# amenity
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# landuse
# landuse
# oneway
# highway
# oneway
# highway
# highway
# access
# layer
# layer
# layer
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# oneway
# highway
# amenity
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# leisure
# highway
# landuse
# highway
# building
# landuse
# amenity
# landuse
# highway
# highway
# highway
# name
# barrier
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# layer
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# oneway
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# oneway
# name
# highway
# highway
# highway
# building
# highway
# name
# highway
# highway
# highway
# highway
# highway
# area
# highway
# oneway
# name
# highway
# highway
# highway
# name
# name
# landuse
# name
# highway
# barrier
# highway
# name
# barrier
# layer
# name
# highway
# highway
# highway
# name
# railway
# name
# name
# highway
# railway
# leisure
# highway
# highway
# name
# highway
# highway
# highway
# name
# landuse
# access
# name
# oneway
# layer
# highway
# highway
# highway
# landuse
# layer
# highway
# area
# highway
# natural
# highway
# natural
# name
# name
# highway
# name
# oneway
# name
# oneway
# oneway
# oneway
# oneway
# oneway
# oneway
# oneway
# leisure
# oneway
# oneway
# oneway
# highway
# highway
# highway
# oneway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# access
# access
# access
# access
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# highway
# highway
# highway
# name
# addr:interpolation
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# amenity
# highway
# highway
# access
# access
# landuse
# access
# access
# oneway
# highway
# waterway
# ref
# highway
# power
# highway
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# railway
# railway
# access
# access
# highway
# access
# access
# access
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# barrier
# barrier
# highway
# highway
# highway
# highway
# highway
# highway
# barrier
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# addr:interpolation
# addr:interpolation
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# addr:interpolation
# highway
# addr:interpolation
# addr:interpolation
# barrier
# leisure
# building
# access
# access
# oneway
# highway
# lanes
# name
# highway
# highway
# name
# name
# name
# name
# alt_name
# highway
# leisure
# name
# ref
# layer
# building
# highway
# name
# highway
# power
# highway
# highway
# highway
# highway
# addr:postcode
# amenity
# highway
# highway
# access
# access
# ref
# power
# power
# power
# power
# name
# access
# name
# name
# name
# name
# highway
# name
# name
# highway
# name
# name
# highway
# name
# name
# power
# name
# oneway
# highway
# name
# power
# name
# access
# building:part
# foot
# foot
# building
# name
# leisure
# layer
# access
# name
# access
# power
# layer
# leisure
# access
# name
# highway
# highway
# highway
# highway
# highway
# barrier
# oneway
# lanes
# name
# landuse
# highway
# highway
# addr:interpolation
# addr:interpolation
# highway
# name
# name
# highway
# highway
# highway
# highway
# highway
# highway
# access
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# access
# access
# name
# access
# oneway
# building
# highway
# highway
# highway
# name
# name
# name
# building
# traffic_calming
# highway
# highway
# highway
# highway
# name
# addr:interpolation
# addr:interpolation
# addr:interpolation
# addr:interpolation
# addr:interpolation
# access
# power
# power
# name
# highway
# landuse
# highway
# oneway
# ref
# power
# lanes
# highway
# area
# building
# hgv
# hgv
# building
# building
# highway
# leisure
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# name
# access
# highway
# highway
# highway
# highway
# highway
# building
# building
# building
# building
# building
# highway
# name
# name
# oneway
# highway
# name
# building
# aeroway
# highway
# oneway
# name
# name
# building
# highway
# highway
# highway
# building
# source
# landuse
# tourism
# landuse
# leisure
# building
# gauge
# building
# landuse
# sport
# landuse
# name
# access
# highway
# access
# access
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# name
# building
# natural
# access
# building
# natural
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# highway
# highway
# highway
# name
# name
# name
# width
# landuse
# name
# highway
# highway
# highway
# highway
# highway
# width
# highway
# highway
# highway
# highway
# waterway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# name
# highway
# building
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# boundary
# name
# bridge
# highway
# highway
# boundary
# boundary
# access
# access
# access
# building
# building
# building
# building
# building
# building
# building
# building
# building
# name
# boundary
# barrier
# barrier
# barrier
# barrier
# barrier
# building
# building
# building
# building
# barrier
# barrier
# barrier
# barrier
# building
# barrier
# barrier
# barrier
# building
# barrier
# barrier
# building
# building
# barrier
# barrier
# name
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# natural
# amenity
# highway
# barrier
# barrier
# barrier
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# barrier
# barrier
# highway
# landuse
# name
# name
# name
# name
# highway
# highway
# highway
# highway
# building
# building
# building
# building
# name
# name
# highway
# barrier
# building
# building
# gauge
# gauge
# name
# name
# highway
# highway
# highway
# highway
# highway
# bridge
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# landuse
# landuse
# landuse
# highway
# highway
# highway
# building
# barrier
# barrier
# barrier
# leisure
# name
# building
# building
# building
# building
# building
# name
# building
# building
# amenity
# building
# building
# name
# building
# building
# highway
# natural
# waterway
# highway
# place
# highway
# building
# building
# highway
# bridge
# highway
# highway
# highway
# barrier
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# waterway
# natural
# natural
# natural
# natural
# natural
# name
# natural
# natural
# barrier
# building
# natural
# natural
# highway
# bicycle
# highway
# highway
# highway
# landuse
# building
# wood
# highway
# highway
# highway
# highway
# natural
# natural
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# building
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# area
# highway
# highway
# highway
# landuse
# building
# building
# building
# building
# building
# building
# building
# leisure
# name
# building
# highway
# highway
# highway
# highway
# name
# landuse
# building
# highway
# building
# highway
# source
# lanes
# lanes
# lanes
# landuse
# lane
# lane
# name
# area
# highway
# landuse
# waterway
# construction
# name
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# building
# highway
# highway
# highway
# highway
# highway
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# highway
# leisure
# access
# name
# building
# building
# building
# building
# building
# building
# building
# name
# highway
# highway
# building
# oneway
# building
# building
# building
# building
# width
# building
# building
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# building
# highway
# highway
# highway
# highway
# name
# building
# leisure
# highway
# highway
# highway
# highway
# tourism
# name
# alt_name
# name
# name
# leisure
# name
# highway
# lanes
# highway
# highway
# highway
# building
# access
# name
# amenity
# layer
# highway
# highway
# leisure
# name
# highway
# foot
# leisure
# building
# building
# highway
# landuse
# highway
# natural
# highway
# name
# building
# building
# name
# building
# name
# name
# name
# landuse
# power
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# foot
# leisure
# highway
# name
# highway
# highway
# highway
# ref
# name
# natural
# building
# landuse
# highway
# highway
# highway
# highway
# lanes
# highway
# highway
# layer
# shop
# highway
# building
# name
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# access
# name
# name
# highway
# building
# highway
# highway
# building
# oneway
# highway
# highway
# source
# highway
# highway
# name
# highway
# highway
# highway
# railway
# highway
# barrier
# highway
# highway
# highway
# highway
# building
# landuse
# building
# building
# building
# building
# building
# highway
# highway
# highway
# highway
# highway
# building
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# layer
# highway
# building
# access
# access
# access
# highway
# highway
# highway
# highway
# highway
# name
# highway
# foot
# highway
# highway
# building
# highway
# highway
# access
# access
# highway
# highway
# access
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# access
# access
# highway
# highway
# building
# highway
# highway
# highway
# highway
# access
# highway
# highway
# highway
# railway
# railway
# railway
# railway
# building
# building
# highway
# highway
# highway
# highway
# foot
# area
# oneway
# highway
# highway
# name
# power
# power
# building
# building
# layer
# ref
# ref
# highway
# highway
# highway
# highway
# highway
# name
# name
# highway
# building
# highway
# access
# oneway
# building
# highway
# highway
# building
# oneway
# highway
# highway
# highway
# highway
# building
# ref
# highway
# access
# barrier
# layer
# name
# name
# name
# name
# name
# name
# name
# name
# ref
# highway
# highway
# oneway
# highway
# landuse
# oneway
# highway
# highway
# lanes
# lanes
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# natural
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# access
# highway
# highway
# highway
# highway
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# ref
# highway
# highway
# highway
# highway
# highway
# power
# building
# building
# ref
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# name
# lanes
# highway
# highway
# lanes
# name
# highway
# name
# lanes
# highway
# highway
# layer
# highway
# highway
# lanes
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# highway
# leisure
# name
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# oneway
# layer
# highway
# oneway
# highway
# highway
# oneway
# oneway
# oneway
# highway
# highway
# highway
# oneway
# highway
# highway
# oneway
# oneway
# highway
# oneway
# highway
# oneway
# highway
# oneway
# leisure
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# lanes
# lanes
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# leisure
# access
# access
# access
# access
# access
# oneway
# access
# man_made
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# name
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# name
# leisure
# highway
# name
# layer
# highway
# oneway
# highway
# source
# highway
# oneway
# name
# highway
# highway
# natural
# layer
# ref
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# landuse
# landuse
# highway
# highway
# highway
# highway
# highway
# oneway
# landuse
# landuse
# landuse
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# foot
# highway
# foot
# building
# building
# power
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# landuse
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# leisure
# amenity
# name
# ref
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# gauge
# gauge
# gauge
# gauge
# gauge
# gauge
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# amenity
# amenity
# access
# access
# access
# building
# building
# building
# building
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# amenity
# amenity
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# power
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# natural
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# power
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# power
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# name
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# waterway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# highway
# sport
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# access
# access
# access
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# amenity
# name
# highway
# access
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# power
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# lanes
# lanes
# highway
# lanes
# lanes
# lanes
# lanes
# lanes
# lanes
# lanes
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# gauge
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# lanes
# highway
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# amenity
# leisure
# highway
# highway
# highway
# highway
# leisure
# lanes
# lanes
# highway
# highway
# lanes
# lanes
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# lanes
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# lanes
# highway
# lanes
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# lanes
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# amenity
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# leisure
# amenity
# leisure
# highway
# highway
# highway
# layer
# waterway
# lanes
# highway
# highway
# highway
# highway
# highway
# ...
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# source
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# man_made
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# man_made
# man_made
# man_made
# man_made
# man_made
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# layer
# oneway
# highway
# highway
# highway
# highway
# lanes
# oneway
# highway
# highway
# name
# width
# lit
# highway
# natural
# name
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# oneway
# highway
# highway
# highway
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# lanes
# power
# power
# power
# name
# highway
# highway
# highway
# landuse
# landuse
# landuse
# landuse
# waterway
# waterway
# landuse
# cemetery
# landuse
# landuse
# waterway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# building
# name
# building
# name
# name
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# leisure
# oneway
# highway
# power
# highway
# highway
# building
# building
# building
# building
# building
# building
# highway
# highway
# amenity
# highway
# highway
# building
# name
# name
# highway
# highway
# leisure
# highway
# lanes
# building
# name
# name
# oneway
# highway
# name
# highway
# landuse
# landuse
# landuse
# landuse
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# leisure
# name
# highway
# highway
# highway
# highway
# highway
# highway
# oneway
# highway
# highway
# highway
# landuse
# landuse
# highway
# landuse
# highway
# name
# name
# building
# building
# building
# building
# building
# building
# building
# building
# highway
# highway
# foot
# oneway
# oneway
# footway
# name
# highway
# oneway
# oneway
# highway
# barrier
# name
# name
# name
# name
# oneway
# highway
# name
# name
# ref
# oneway
# oneway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# name
# bridge
# addr:interpolation
# addr:interpolation
# highway
# power
# name
# highway
# building
# name
# landuse
# highway
# building
# highway
# aeroway
# landuse
# junction
# highway
# highway
# name
# name
# building
# building
# building
# building
# building
# building
# building
# building
# building
# area
# lanes
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# layer
# highway
# tunnel
# highway
# leisure
# highway
# name
# oneway
# oneway
# access
# highway
# highway
# highway
# highway
# name
# psv
# building
# name
# building
# leisure
# building
# building
# name
# highway
# name
# highway
# psv
# oneway
# layer
# building
# building
# building
# oneway
# highway
# highway
# highway
# power
# highway
# highway
# highway
# bridge
# highway
# highway
# highway
# natural
# barrier
# barrier
# barrier
# barrier
# leisure
# bicycle
# leisure
# highway
# description
# landuse
# leisure
# addr:city
# leisure
# addr:city
# leisure
# building
# leisure
# cables
# highway
# addr:city
# barrier
# barrier
# leisure
# leisure
# bridge
# power
# building
# leisure
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# highway
# highway
# highway
# leisure
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# highway
# highway
# building
# building
# highway
# highway
# highway
# leisure
# highway
# building
# amenity
# highway
# leisure
# building
# leisure
# highway
# building
# highway
# highway
# highway
# landuse
# bicycle
# highway
# landuse
# landuse
# highway
# highway
# landuse
# highway
# leisure
# leisure
# building
# building
# natural
# building
# highway
# layer
# building:part
# building
# amenity
# embankment
# highway
# building:color
# building:material
# amenity
# highway
# highway
# highway
# highway
# highway
# area:highway
# highway
# amenity
# leisure
# building
# highway
# access
# addr:city
# amenity
# bicycle
# highway
# landuse
# highway
# landuse
# highway
# embankment
# alt_name
# layer
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# access
# building
# building
# building
# building
# building
# leisure
# highway
# building
# building
# building
# building
# building
# building
# building
# building
# building
# access
# building
# building
# building
# building
# building
# building
# building
# leisure
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# building
# bicycle
# addr:interpolation
# addr:interpolation
# addr:interpolation
# addr:interpolation
# addr:interpolation
# covered
# building
# barrier
# highway
# highway
# addr:city
# bridge
# bridge
# bridge
# bridge
# bridge
# bridge
# bridge
# bridge
# construction
# construction
# construction
# construction
# construction
# construction
# construction
# bridge
# bridge
# bridge
# bridge
# construction
# construction
# construction
# construction
# bridge
# bridge
# bridge
# bridge
# construction
# bridge
# bridge
# construction
# construction
# bridge
# construction
# construction
# construction
# construction
# construction
# construction
# construction
# highway
# highway
# highway
# highway
# building
# highway
# leisure
# landuse
# highway
# highway
# highway
# building
# highway
# highway
# construction
# highway
# highway
# highway
# highway
# highway
# landuse
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# highway
# power
# highway
# leisure
# barrier
# highway
# highway

# %%
# Now I am going to check if the tags contain any problem. I am going to use regular expressions to check if the 
# tag contain lower, lower colon or problem characters.
lower = re.compile(r'^([a-z]|_)*$') # tags that contain only lowercase letters and are valid
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$') # for tags with a colon in their names
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]') # for tags with problematic characters

# %%
# counting all the values in attribute "k" that match the regex pattern
lower_c = 0 # counter for lower cased values
lower_col_c = 0 # counter of lower cased values with colon
problemchar_c = 0 # counter for problematic values
other = 0 # counter for the rest of the values that fall in the regex patterns   

for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        if lower.search(elem.attrib['k']):
            lower_c += 1
        elif lower_colon.search(elem.attrib['k']):
            lower_col_c += 1
        elif problemchars.search(elem.attrib['k']):
            problemchar_c += 1
        else:
            other += 1

print("lower: {} lower_colon: {} problemchar: {} other: {}".format(lower_c, lower_col_c, problemchar_c, other))
# Out:
# lower: 80541 lower_colon: 1590 problemchar: 0 other: 38

# %%
# I am now going to put the patterns in a dictionary.
counted_patterns = {"lower" : 0, "lower_colon" : 0, "problemchars" : 0, "others" : 0}
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        if lower.search(elem.attrib["k"]):
            counted_patterns["lower"] += 1
        elif lower_colon.search(elem.attrib["k"]):
            counted_patterns["lower_colon"] += 1
        elif problemchars.search(elem.attrib["k"]):
            counted_patterns["problemchars"] += 1
        else:
            counted_patterns["others"] += 1
print(counted_patterns)
# Out:
# {'lower': 80541, 'lower_colon': 1590, 'problemchars': 0, 'others': 38}

# %%
# now I will check for the values corresponding to the 'v' attribute. 
# I am also going to check what type of object it is.
for event, elem in ET.iterparse(sample_file):
    if elem.tag == "tag":
        if elem.attrib["k"] == "addr:street" or elem.attrib["k"] == "addr:postcode":
            print(elem.attrib["v"], type(elem.attrib["v"]))
            break
# Out:
# Old Delhi Gurgaon Road <class 'str'>

# %%
# now lets make a dictionary that will contain a list of postcodes and street addresses 
# extracted from those attributes
street_and_post = {"street" : [], "post_code" : []}
for event, elem in ET.iterparse(bigger_sample_file):  
    if elem.tag == "tag":
        if elem.attrib["k"] == "addr:street":
            street_and_post["street"].append(elem.attrib["v"])
        if elem.attrib["k"] == "addr:postcode":
            if len(elem.attrib["v"]) == 6:
                street_and_post["post_code"].append(elem.attrib["v"])
            else:
                print("Bad postcode {}".format(elem.attrib["v"]))
print()
print(street_and_post["street"])
print()
print(street_and_post["post_code"])

# There is a post code in the data that does not match the right post code pattern.
# Out:
# Bad postcode 2013010
# Bad postcode 110 021
# Bad postcode 1100002
#
# ['Block A1', 'Old Delhi Gurgaon Road', 'Aurangzeb Road', 'Block A1', 'Block A1', 'Block A1', 'Block A1', 'Block A1', 'Bhavani Kunj, Vasant Kunj', 'Block A', 'Sector 46', 'Block B', 'South City 2', 'South City II', 'South City II', 'Sector 17C', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'Sector 46', 'S1', 'S1', 'S1', 'S1', 'S1', 'S1', 'Palam Vihar', 'Palam Vihar', 'Palam Vihar', 'Palam Vihar', 'Palam Vihar', 'Palam Vihar', 'Palam Vihar', 'Sector 46', 'Sector 46', 'Sector 46', 'janakpuri', 'NIT', 'Connaught Circus', '649-6th Floor, Tower A Spaze iTechPark', 'palika bazar road', 'shastri nagar', 'delhi', 'Chuna Mandi, Paharganj', 'South Extension', 'Chattarpur Main Road', 'Shiv Arcade,aacharya niketan,mayor vihar ph-1', 'Vikas Marg', 'Ansari Nagar', 'DCE College', 'Asaf Ali Road', 'MAMURA Road', 'Hanuman Market Harola', 'Vikas Marg', 'Sector 44', 'Dr. Sushila Naiyar Marg', 'Vikas Marg', 'Rao Tula Ram Marg', 'Block G, Patel Nagar 3, Ghaziabad 201001, UP', 'Phi-02', 'G-5, Sector-16, Rohini, New Delhi-110089', 'Green Park Main Market', 'Sector-18', 'Bada Bazaar', 'Nyaya Marg', 'Qutram Lane', 'Mathura Road', '2nd Floor, Munshi Lal Building, Connaught Place', 'Bilaspur Khurd, Gurgaon', 'Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat Nagar, Pahargan', 'Defense Colony', 'Nehru Place Road', 'Sai Chowk, Madhu Vihar', 'Street No.3', 'C - 99, Sector - 4, Sector 4 Noida, Block C, Sector 4, Noida,', 'Golf Course Extension Road', 'Idgah Road', 'suchitra kriplani marg', 'Sansanwal Marg', 'Aruna Asif Ali Marg', 'Ashoka Road', 'Sector 6', 'HSIIDC Industrial Estate', 'Sector 56', 'Kasturba Gandhi Marg', 'Nelson Mandela Marg', 'Indraprastha Marg', 'Sector 6', 'C Block, Janakpuri', 'Mathura Road', 'Sanjay Nagar', 'Gharoli Road, Mayur Vihar Phase - 3', 'Sector 6', 'Sector 6', 'Sector 6', 'Bahadur Shah Zafar Marg', 'Barakhamba Road', 'Barakhamba Road', 'Sadhbhawna Marg', 'HPR School Back Road', 'Street E, Munirka DDA Flats', 'Jawaharlal Nehru University', 'Abdul Gaffar Khan Marg', 'Old Delhi Gurgaon Road', 'U-12', 'lothian road, Kashmere gate', 'Road 210', 'Vasant Marg', 'Sector-56', 'Mahatma Gandhi Marg', 'Under Hill Lane', 'Press Enclave Road', 'Sector-21A', 'Brahm Colony', 'Vasundhara Enclave', 'Near Hari Masjid, Jogabai Extn, Okhla', 'Vardhman Times Plaza, Plot 13, DDA Community Centre, Road 44, Pitampura', 'Off Sohna-Gurgaon Road', 'Block No.1', 'Block No.1', 'Block No.1', 'Block No.1', 'Block No.1', 'Block No.1', 'Block No.1', 'Block No.1', 'A-6', 'Modern Industrial Estate Part-A', 'Modern Industrial Estate Part-A', 'Block No.2', 'Block No.2', 'Block No.2', 'Block No.2', 'Block No.2', 'Block No.2', 'Block No.3', 'Block No.3', 'Block No.3', 'Block No.3', 'Block No.3', 'Block No.5', 'Block No.5', 'Block No.5', 'Block No.6', 'Block No.6', 'Block No.6', 'Block No.7', 'Block No.7', 'Block No.7', 'Block No.7', 'Block No.8', 'Block No.8', 'Block No.8', 'Block No.9', 'Block No.9', 'Block No.10', 'Block No.10', 'Block No.10', 'Block No.10', 'Block No.11', 'Block No.11', 'Block No.11', 'Block No.11', 'Block No.12', 'Block No.12', 'Block No.12', 'Block No.13', 'Block No.13', 'Block No.14', 'Block No.14', 'Block No.14', 'Block No.14', 'DLF Phase 4', 'Mahatma Gandhi Marg', 'Sector-3, Rohini', 'Bhagwan Mahavir Marg', 'Bhagwan Mahavir Marg', 'Sector 17, Vasundhara', 'Netaji Subhash Place', 'Sector-56', 'Vasundhara Enclave', 'Surajkund Road']
#
# ['122001', '110011', '110070', '122002', '122018', '122018', '122018', '122001', '100006', '100006', '100006', '100006', '100006', '100006', '122001', '122001', '122001', '122001', '122001', '122001', '122001', '110007', '201307', '110001', '122018', '110085', '110043', '110055', '110074', '110091', '110029', '110042', '110042', '110002', '201301', '110092', '122002', '110077', '201014', '110092', '201308', '110016', '250101', '110017', '110009', '110044', '110001', '122413', '110055', '110024', '110092', '110092', '110092', '110092', '110053', '201301', '110032', '201014', '110016', '110070', '110001', '110075', '121004', '201001', '122011', '110001', '110070', '201301', '110075', '110058', '110052', '110008', '110044', '201002', '110096', '110075', '110075', '110075', '110096', '201001', '110091', '110085', '110042', '110085', '110085', '201301', '110067', '110070', '122001', '110006', '110057', '122011', '110029', '122001', '201306', '201301', '110096', '201314', '110025', '110034', '122102', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110063', '124507', '124507', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110087', '110092', '110085', '110088', '110088', '201012', '110085', '122011', '110096', '121004']

# %%
# Pin codes in Delhi start with 11. However, in this dataset a large number of entries 
# contain invalid pin code data.
# My first attempt to fix these anomalies in the data is to compile simple regular expressions
# that checks the first two strings of the pin code. If a corrupt entry is found 
# the first two strings will be resubstituted with 11.
# The other regex validates a pin code only if it is 6 digits long. 
compiler = re.compile(r'^10') 
pin_validator = re.compile(r'^[1-9][0-9]{5}$') 

invalid_pin_codes = [] # making a container for invalid_pin_codes
counter = 0 # a counter variable to count the number of pin codes in this dataset
index = 0 # an index to keep track of bad pin codes
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        if elem.attrib["k"] == "addr:postcode":
            counter += 1
            match = compiler.search(elem.attrib["v"]) # check for pin codes that dont start with 11
            pin_match = pin_validator.search(elem.attrib["v"]) # check for 6 digit pin code
            if match:
                index += 1 # increament index if match is True
                print("-->", elem.attrib["v"], index, "Found", match.group())
            elif not pin_match:
                index += 1 # increament index if pin_match is False
                print("-->", elem.attrib["v"], index, "Found")
            else:
                print(elem.attrib["v"])
print()
print("-" * 50)
print("{} Number of pin codes\n{} Invalid pin codes\n{} Valid pin codes".format(counter, index,(counter - index)))
print('{:.2f}% {}'.format(((index/counter)* 100), "Bad entries"))
# Out:
# 122001
# 110011
# 110070
# 122002
# 122018
# 122018
# 122018
# 122001
# --> 100006 1 Found 10
# --> 100006 2 Found 10
# --> 100006 3 Found 10
# --> 100006 4 Found 10
# --> 100006 5 Found 10
# --> 100006 6 Found 10
# 122001
# 122001
# 122001
# 122001
# 122001
# 122001
# 122001
# 110007
# 201307
# 110001
# 122018
# 110085
# 110043
# 110055
# 110074
# 110091
# 110029
# 110042
# 110042
# 110002
# --> 2013010 7 Found
# 201301
# 110092
# 122002
# 110077
# 201014
# 110092
# 201308
# 110016
# 250101
# 110017
# --> 110 021 8 Found
# 110009
# 110044
# 110001
# 122413
# 110055
# 110024
# 110092
# 110092
# 110092
# 110092
# 110053
# 201301
# 110032
# 201014
# 110016
# 110070
# 110001
# 110075
# 121004
# 201001
# 122011
# 110001
# 110070
# 201301
# --> 1100002 9 Found
# 110075
# 110058
# 110052
# 110008
# 110044
# 201002
# 110096
# 110075
# 110075
# 110075
# 110096
# 201001
# 110091
# 110085
# 110042
# 110085
# 110085
# 201301
# 110067
# 110070
# 122001
# 110006
# 110057
# 122011
# 110029
# 122001
# 201306
# 201301
# 110096
# 201314
# 110025
# 110034
# 122102
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110063
# 124507
# 124507
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110092
# 110085
# 110088
# 110088
# 201012
# 110085
# 122011
# 110096
# 121004
#
# --------------------------------------------------
# 167 Number of pin codes
# 9 Invalid pin codes
# 158 Valid pin codes
# 5.39% Bad entries

# %%
# I am going to work on the street names now. My immediate approach for getting all the bad street names
# is to first make a list of all the expected street names.
# Then iterate through the tags where the "k" attribute is "addr:street"
# If I find a street name, I split it and take its last word.
# If the last words in the street names dont match the street names in the expected list 
# I will add them to a dictionary set.

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE) # regex that looks for the last word in a line


expected = ['Delhi', 'Street', 'Nagar', 'Sadan', 'Marg', 'Road', 'Avenue', 'Circle', 'Mayur'
            'Place', 'Sector', 'Vihar', 'Enclave', 'Block', 'Chowk', 'Colony', 'Mandir', 'Market', 'Place', 'Lane',
            'Estate', 'Bazaar', 'Kunj', 'Circus', 'Extension', 'College']

counter = 0 # counter to check total number of street names
street_dict = defaultdict(set) # container for the unexpected values
for event, elem in ET.iterparse(bigger_sample_file, events=("start", )):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib["k"] == "addr:street":
                counter += 1 # counter increments if street name is found
                match = street_type_re.search(tag.attrib["v"]) # Last name of street names
                # are referenced to a variable match
                if match: # if a pattern matches successfully
                    street_name = match.group() # the matched pattern is .
                    if street_name not in expected:
                        street_dict[street_name].add(tag.attrib["v"])
pprint(dict(street_dict))
print()
print("{:.2f}% {}".format((len(dict(street_dict))/counter)*100, "Unexpected street names"))
# Out:
# {'17C': {'Sector 17C'},
#  '2': {'South City 2'},
#  '210': {'Road 210'},
#  '3': {'Gharoli Road, Mayur Vihar Phase - 3'},
#  '4': {'DLF Phase 4'},
#  '44': {'Sector 44'},
#  '46': {'Sector 46'},
#  '56': {'Sector 56'},
#  '6': {'Sector 6'},
#  'A': {'Block A'},
#  'A-6': {'A-6'},
#  'A1': {'Block A1'},
#  'B': {'Block B'},
#  'Delhi-110089': {'G-5, Sector-16, Rohini, New Delhi-110089'},
#  'Flats': {'Street E, Munirka DDA Flats'},
#  'Gurgaon': {'Bilaspur Khurd, Gurgaon'},
#  'Harola': {'Hanuman Market Harola'},
#  'II': {'South City II'},
#  'Janakpuri': {'C Block, Janakpuri'},
#  'NIT': {'NIT'},
#  'No.1': {'Block No.1'},
#  'No.10': {'Block No.10'},
#  'No.11': {'Block No.11'},
#  'No.12': {'Block No.12'},
#  'No.13': {'Block No.13'},
#  'No.14': {'Block No.14'},
#  'No.2': {'Block No.2'},
#  'No.3': {'Block No.3', 'Street No.3'},
#  'No.5': {'Block No.5'},
#  'No.6': {'Block No.6'},
#  'No.7': {'Block No.7'},
#  'No.8': {'Block No.8'},
#  'No.9': {'Block No.9'},
#  'Noida,': {'C - 99, Sector - 4, Sector 4 Noida, Block C, Sector 4, Noida,'},
#  'Okhla': {'Near Hari Masjid, Jogabai Extn, Okhla'},
#  'Pahargan': {'Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat '
#               'Nagar, Pahargan'},
#  'Paharganj': {'Chuna Mandi, Paharganj'},
#  'Part-A': {'Modern Industrial Estate Part-A'},
#  'Phi-02': {'Phi-02'},
#  'Pitampura': {'Vardhman Times Plaza, Plot 13, DDA Community Centre, Road 44, '
#                'Pitampura'},
#  'Rohini': {'Sector-3, Rohini'},
#  'S1': {'S1'},
#  'Sector-18': {'Sector-18'},
#  'Sector-21A': {'Sector-21A'},
#  'Sector-56': {'Sector-56'},
#  'U-12': {'U-12'},
#  'UP': {'Block G, Patel Nagar 3, Ghaziabad 201001, UP'},
#  'University': {'Jawaharlal Nehru University'},
#  'Vasundhara': {'Sector 17, Vasundhara'},
#  'delhi': {'delhi'},
#  'gate': {'lothian road, Kashmere gate'},
#  'iTechPark': {'649-6th Floor, Tower A Spaze iTechPark'},
#  'janakpuri': {'janakpuri'},
#  'marg': {'suchitra kriplani marg'},
#  'nagar': {'shastri nagar'},
#  'ph-1': {'Shiv Arcade,aacharya niketan,mayor vihar ph-1'},
#  'road': {'palika bazar road'}}
#
# 30.16% Unexpected street names

# %%
# creating a nested dictionary containing top level tag attributes 
# and their corresponding values.
# before I start populating the dictionary, first thing to do is to 
# create a list of expected tags
CREATED = ["version", "changeset", "timestamp", "user", "uid"] # list of expected tags
node_lst = [] # The dictionary will be appended to this list as it keeps getting updated
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        nodes = {"created": {}, "type" : elem.tag} # dictionary that will store attributes and their values
        for tag in elem.attrib: # Iterate over top level element tags
            if tag in CREATED: # If tags match the CREATED list
                nodes["created"][tag] = elem.attrib[tag] # add the tag to the dictionary
                                                         # with elem.attrib[tag] as it value
        node_lst.append(nodes) # append dict to the list

# %%
# checking the node_lst
node_lst[0]
# Out:
# {'created': {'changeset': '46299189',
#   'timestamp': '2017-02-22T08:42:55Z',
#   'uid': '3029661',
#   'user': 'saikabhi',
#   'version': '53'},
#  'type': 'node'}

# %%
# check node_lst again
node_lst[1]
# Out:
# {'created': {'changeset': '505778',
#   'timestamp': '2007-09-23T02:41:01Z',
#   'uid': '5456',
#   'user': 'H_S_Rai',
#   'version': '1'},
#  'type': 'node'}

# %%
# expanding on to the previous code block
# most of the code remains the same except for the addition of "lat" and "lon" attrib
CREATED = ["version", "changeset", "timestamp", "user", "uid"] # list of expected tags
node_lst = [] # append an upadated dictionary to this list
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        nodes = {"created": {}, "type" : elem.tag} # dictionary that will store attributes and their values
        if "lat" in elem.attrib and "lon" in elem.attrib: # if "lat" and "lon" in top level attrib
            # add a new key to the dict and assign floating "lat"/"lon" attributes as its val. 
                nodes["pos"] = [float(elem.attrib["lat"]), float(elem.attrib["lon"])]
        for tag in elem.attrib:
            if tag == "lat" or tag == "lon": # ignore "lat"/"lon" attributes if they are in tag
                continue
            if tag in CREATED: # update dictionary as usual if tag found in CREATED
                nodes["created"][tag] = elem.attrib[tag]
        
        node_lst.append(nodes) # append dict to the list

# %%
# check the updated list
node_lst[:3]
# Out:
# [{'created': {'changeset': '46299189',
#    'timestamp': '2017-02-22T08:42:55Z',
#    'uid': '3029661',
#    'user': 'saikabhi',
#    'version': '53'},
#   'pos': [28.6138967, 77.2159562],
#   'type': 'node'},
#  {'created': {'changeset': '505778',
#    'timestamp': '2007-09-23T02:41:01Z',
#    'uid': '5456',
#    'user': 'H_S_Rai',
#    'version': '1'},
#   'pos': [28.5426036, 77.1680173],
#   'type': 'node'},
#  {'created': {'changeset': '505778',
#    'timestamp': '2007-09-23T02:39:15Z',
#    'uid': '5456',
#    'user': 'H_S_Rai',
#    'version': '1'},
#   'pos': [28.5421814, 77.1648674],
#   'type': 'node'}]

# %%
# completing the code from the previous block. Adding the missing parts to the code to prepare the data model needed 
# before injected it to a database.

problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
CREATED = ["version", "changeset", "timestamp", "user", "uid"] # list of expected tags
nodes_lst = [] # This list will append updated dictionary

for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        nodes = {"created": {}, "type" : elem.tag} # dictionary that will store attributes and their values
        if "lat" in elem.attrib and "lon" in elem.attrib:
                nodes["pos"] = [float(elem.attrib["lat"]), float(elem.attrib["lon"])]
        
        for tag in elem.attrib:
            if tag == "lat" or tag == "lon":
                continue
            if tag in CREATED:
                nodes["created"][tag] = elem.attrib[tag]
            else:
                nodes[tag] = elem.attrib[tag]
        
        for data in elem.iter("tag"):
            match = problemchars.search(data.attrib["k"])
            if match:
                continue
            
            elif data.attrib["k"].startswith("addr:"):
                address = data.attrib["k"].split(":", 2)
                nodes["address"] = {}
                if len(address) == 2:
                    nodes["address"][address[1]] = data.attrib["v"]
            else:
                nodes[data.attrib["k"]] = data.attrib["v"]
        
        node_ref = []        
        for nd_tag in elem.iter("nd"):
            node_ref.append(nd_tag.attrib["ref"])
        
        if len(node_ref) > 0:
            nodes["node_ref"] = node_ref
        
        nodes_lst.append(nodes)

# %%
# checking if "address" key is in the dictionary
for keys in nodes_lst:
    if "address" in keys.keys():
        print(keys["address"])
# Out:
# {'housenumber': '38'}
# {'postcode': '122001'}
# {'housenumber': '12'}
# {'housenumber': '40'}
# {'housenumber': '6'}
# {'housenumber': '19'}
# {'housenumber': '30'}
# {'housenumber': '48'}
# {'housenumber': '63B'}
# {'housenumber': '37'}
# {'housenumber': '53'}
# {'housenumber': '35'}
# {'housenumber': '24'}
# {'housenumber': '6'}
# {'housenumber': '8'}
# {'housenumber': '75'}
# {'housenumber': '114'}
# {'housenumber': '1425'}
# {'housenumber': '42'}
# {'housenumber': '512'}
# {'housenumber': '21'}
# {'housenumber': '18'}
# {'housenumber': '15'}
# {'housenumber': 'todo'}
# {'housenumber': '1359'}
# {'housenumber': '1342'}
# {'housenumber': '1292'}
# {'housenumber': '1446'}
# {'housenumber': '1678'}
# {'housenumber': '1475'}
# {'housenumber': '1496'}
# {'housenumber': '1847'}
# {'housenumber': '1566'}
# {'housenumber': '1650'}
# {'housenumber': '1900'}
# {'housenumber': '2036'}
# {'housenumber': '2427'}
# {'housenumber': '2571'}
# {'housenumber': '771'}
# {'housenumber': '652'}
# {'housenumber': '600'}
# {'housenumber': '630'}
# {'housenumber': '600'}
# {'housenumber': '630'}
# {'housenumber': 'C152'}
# {'housenumber': '2565A'}
# {'housenumber': '2469'}
# {'housenumber': '651'}
# {'housenumber': '2221'}
# {'housenumber': '2426'}
# {'housenumber': '2440'}
# {'housenumber': '1365'}
# {'postcode': '110007'}
# {'housenumber': '1111'}
# {'housenumber': '1857'}
# {'housenumber': '817'}
# {'housenumber': 'S-483'}
# {'housenumber': 'S-513'}
# {'housenumber': '383'}
# {'housenumber': 'S-327'}
# {'housenumber': 'S-407'}
# {'housenumber': 'S-447'}
# {'housenumber': 'W-91'}
# {'housenumber': '145'}
# {'housenumber': 'W-42'}
# {'housenumber': '98'}
# {'housenumber': 'W-2'}
# {'street': 'janakpuri'}
# {'housenumber': '276'}
# {'housenumber': 'E209'}
# {'housename': 'Sector-24'}
# {'housenumber': '46'}
# {'housenumber': '1069'}
# {'housenumber': '738'}
# {'housenumber': '1,20'}
# {'housenumber': '11'}
# {'housenumber': '1'}
# {'housenumber': '37,1'}
# {'housenumber': '30,1'}
# {'housenumber': '1'}
# {'housenumber': '12'}
# {'housenumber': '25'}
# {'housenumber': '1'}
# {'housenumber': '47,1'}
# {'housename': 'A2-2'}
# {'housename': 'KE-1'}
# {'housename': 'W3-1'}
# {'housename': 'BPS'}
# {'housenumber': 'G-59'}
# {'housename': 'Mahagun Metro Mall'}
# {'housename': 'A7-11'}
# {'housenumber': '649'}
# {'street': 'palika bazar road'}
# {'housename': 'VANDANA APPARMENT'}
# {'street': 'shastri nagar'}
# {'housenumber': 'B-1'}
# {'housenumber': 'B-2'}
# {'housenumber': 'B-13'}
# {'housenumber': 'B-214'}
# {'housenumber': 'B-111'}
# {'housenumber': 'E-69'}
# {'housenumber': 'B-167'}
# {'housenumber': 'C-215'}
# {'housenumber': 'D-518'}
# {'housenumber': 'A-41'}
# {'housenumber': 'D-364'}
# {'housenumber': 'D-397'}
# {'housenumber': 'B-116'}
# {'housenumber': 'C-236'}
# {'housenumber': '110010'}
# {'housenumber': '30'}
# {'housenumber': '42'}
# {'housenumber': '12'}
# {'housenumber': '16'}
# {'housenumber': '11/1903,'}
# {'street': 'South Extension'}
# {'postcode': '110074'}
# {'housenumber': 'A-24'}
# {'housenumber': 'C-3'}
# {'housenumber': 'B-30'}
# {'housenumber': 'B-6'}
# {'housenumber': 'C-6'}
# {'housenumber': 'D-115'}
# {'housenumber': 'C-3'}
# {'housenumber': 'C-18'}
# {'housenumber': 'C-17'}
# {'housenumber': 'B-7'}
# {'housenumber': 'B-27'}
# {'housenumber': 'A-3'}
# {'housenumber': 'A-5'}
# {'housenumber': '1'}
# {'housenumber': '14'}
# {'housenumber': '863'}
# {'housenumber': '526'}
# {'housenumber': '447'}
# {'housenumber': 'A2/A2 3rd Floor'}
# {'housenumber': '44, Defence Enclave,'}
# {'housenumber': 'Boys Hostel, AIIMS'}
# {'housenumber': '122'}
# {'housenumber': '37'}
# {'housenumber': '53'}
# {'housenumber': '82'}
# {'postcode': '110042'}
# {'street': 'DCE College'}
# {'housenumber': '1/8B'}
# {'housenumber': 'Shop No. 3, Sec 66'}
# {'housenumber': 'Sec 5'}
# {'city': 'Muradnagar'}
# {'postcode': '201301'}
# {'housenumber': '319'}
# {'city': 'New Delhi'}
# {'housenumber': 'P-129'}
# {'city': 'Meerut'}
# {'housenumber': '1932A'}
# {'housenumber': '1'}
# {'housenumber': 'Sector 10'}
# {'housenumber': 'A-124 Rajhans Plaza, Ahinsa Khand 1'}
# {'housenumber': 'F-39/B'}
# {'street': 'Rao Tula Ram Marg'}
# {'housenumber': 'G-1'}
# {'housenumber': 'D-341, sector-10, noida, up'}
# {'housenumber': 'C-3392'}
# {'housenumber': 'C-3416'}
# {'housenumber': 'C-3469'}
# {'housenumber': 'C-3679'}
# {'housenumber': 'C-3139'}
# {'housenumber': 'C-3018'}
# {'housenumber': 'C-3058'}
# {'housenumber': 'C-3082A'}
# {'housenumber': 'C-3149'}
# {'housenumber': 'C-3184'}
# {'housenumber': 'C-3193'}
# {'housenumber': 'C-3270'}
# {'housenumber': 'C-3303'}
# {'housenumber': 'C-3324'}
# {'housenumber': 'C-3375'}
# {'subdistrict': 'Dadri'}
# {'street': 'G-5, Sector-16, Rohini, New Delhi-110089'}
# {'street': 'Green Park Main Market'}
# {'housenumber': 'B-1/3'}
# {'postcode': '250101'}
# {'housenumber': 'S-39A'}
# {'postcode': '110 021'}
# {'housenumber': '2152'}
# {'housenumber': 'A-24/10'}
# {'housenumber': 'N-96'}
# {'postcode': '122413'}
# {'postcode': '110055'}
# {'housenumber': 'D-33'}
# {'street': 'Nehru Place Road'}
# {'housenumber': 'C-5'}
# {'postcode': '110092'}
# {'postcode': '110092'}
# {'postcode': '110092'}
# {'housenumber': 'C-32'}
# {'housenumber': 'C-3435'}
# {'housenumber': 'C-3496'}
# {'housenumber': 'C-3531'}
# {'housenumber': 'C-3591'}
# {'postcode': '201301'}
# {'street': 'Golf Course Extension Road'}
# {'street': 'Idgah Road'}
# {'housenumber': '111'}
# {'housenumber': '168'}
# {'housenumber': '2'}
# {'housenumber': '24'}
# {'housenumber': '278'}
# {'housenumber': '317'}
# {'housenumber': '357'}
# {'housenumber': '406'}
# {'housenumber': '456'}
# {'housenumber': '496'}
# {'housenumber': '85'}
# {'street': 'suchitra kriplani marg'}
# {'postcode': '110016'}
# {'housenumber': 'Sector B1, Vasant Kunj'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'buildingnumber': 'Tower 4'}
# {'buildingnumber': 'Tower 15'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'even'}
# {'interpolation': 'odd'}
# {'interpolation': 'odd'}
# {'interpolation': 'odd'}
# {'interpolation': 'odd'}
# {'street': 'Ashoka Road'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'housenumber': 'A3-2'}
# {'housenumber': 'W1-2'}
# {'housenumber': 'Plot 27'}
# {'housenumber': 'Plot 118'}
# {'housename': '3M'}
# {'city': 'Ghaziabad'}
# {'housename': 'State Bank of India'}
# {'housename': 'Aabhas Society'}
# {'postcode': '110001'}
# {'housenumber': '2'}
# {'postcode': '201301'}
# {'housenumber': '128'}
# {'housenumber': '4, Block B, IP Estate'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'housenumber': 'Plot 39B'}
# {'postcode': '110058'}
# {'postcode': '110052'}
# {'postcode': '110008'}
# {'housename': 'H-5/B-1, Mohan Coop Industrial Area'}
# {'housenumber': '1-12'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'postcode': '110096'}
# {'housenumber': 'Plot 11'}
# {'housenumber': 'Plot 33'}
# {'housenumber': 'Plot 28'}
# {'postcode': '110096'}
# {'housenumber': '3'}
# {'street': 'Barakhamba Road'}
# {'street': 'Barakhamba Road'}
# {'postcode': '201001'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'housenumber': '4-A'}
# {'postcode': '110091'}
# {'housenumber': '10'}
# {'housenumber': '1'}
# {'housenumber': 'D-4'}
# {'suburb': 'Uttam Nagar'}
# {'postcode': '110085'}
# {'postcode': '110042'}
# {'housenumber': 'F-2/67'}
# {'postcode': '110085'}
# {'housenumber': 'Naya Bans, Naya Bans Village'}
# {'postcode': '110067'}
# {'street': 'Jawaharlal Nehru University'}
# {'postcode': '110070'}
# {'postcode': '122001'}
# {'housenumber': '12/28'}
# {'postcode': '110006'}
# {'street': 'Road 210'}
# {'housenumber': 'Basement, E65'}
# {'street': 'Sector-56'}
# {'street': 'Mahatma Gandhi Marg'}
# {'street': 'Under Hill Lane'}
# {'street': 'Press Enclave Road'}
# {'housenumber': '673/9'}
# {'housenumber': 'N14/35'}
# {'postcode': '201306'}
# {'street': 'Sector-21A'}
# {'housenumber': 'Opposite water pump no. 2'}
# {'housenumber': 'B-13'}
# {'postcode': '201314'}
# {'city': 'Ghaziabad'}
# {'housenumber': 'R-79'}
# {'housenumber': 'Floor 3'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'postcode': '122102'}
# {'housenumber': '2'}
# {'housenumber': '14'}
# {'housenumber': '24'}
# {'housenumber': '34'}
# {'housenumber': '44'}
# {'housenumber': '55'}
# {'housenumber': '65'}
# {'housenumber': '75'}
# {'housenumber': '25'}
# {'housenumber': '644'}
# {'housenumber': '654'}
# {'housenumber': '86'}
# {'housenumber': '96'}
# {'housenumber': '106'}
# {'housenumber': '116'}
# {'housenumber': '86'}
# {'housenumber': '96'}
# {'housenumber': '128'}
# {'housenumber': '138'}
# {'housenumber': '148'}
# {'housenumber': '158'}
# {'housenumber': '168'}
# {'housenumber': '178'}
# {'housenumber': '188'}
# {'housenumber': '198'}
# {'housenumber': '208'}
# {'housenumber': '218'}
# {'housenumber': '228'}
# {'housenumber': '237'}
# {'housenumber': '247'}
# {'housenumber': '257'}
# {'housenumber': '267'}
# {'housenumber': '276'}
# {'housenumber': '286'}
# {'housenumber': '296'}
# {'housenumber': '306'}
# {'housenumber': '316'}
# {'housenumber': '326'}
# {'housenumber': '336'}
# {'housenumber': '346'}
# {'housenumber': '356'}
# {'housenumber': '364'}
# {'housenumber': '374'}
# {'housenumber': '384'}
# {'housenumber': '394'}
# {'housenumber': '404'}
# {'housenumber': '414'}
# {'housenumber': '424'}
# {'housenumber': '433'}
# {'housenumber': '443'}
# {'housenumber': '452'}
# {'housenumber': '462'}
# {'housenumber': '472'}
# {'housenumber': '482'}
# {'housenumber': 'Tower R'}
# {'postcode': '110092'}
# {'housenumber': '4-b block'}
# {'housenumber': 'G-29/26'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'street': 'Bhagwan Mahavir Marg'}
# {'street': 'Bhagwan Mahavir Marg'}
# {'street': 'Sector 17, Vasundhara'}
# {'street': 'Netaji Subhash Place'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'interpolation': 'all'}
# {'street': 'Sector-56'}

# %%
# checking for cuisines
for keys in nodes_lst:
    if "cuisine" in keys.keys():
        print(keys["cuisine"])
# Out:
# South Indian
# indian
# burger
# vegetarian
# burger
# pizza
# indian
# indian
# burger
# regional
# indian;chinese;tea
# regional
# pizza

# %%
# checking if amenity key is there in the dictionary
for keys in nodes_lst:
    if "amenity" in keys.keys():
        print(keys["amenity"])
# Out:
# bank
# bank
# pharmacy
# fast_food
# cinema
# fuel
# pharmacy
# atm
# bank
# atm
# fuel
# atm
# fuel
# fuel
# bank
# parking
# fuel
# school
# police
# post_box
# fast_food
# restaurant
# parking
# hospital
# pharmacy
# restaurant
# bank
# hospital
# parking
# bank
# fuel
# fuel
# atm
# atm
# school
# police
# school
# parking
# fuel
# bank
# hospital
# doctors
# atm
# hospital
# bank
# toilets
# toilets
# hospital
# parking
# restaurant
# place_of_worship
# restaurant
# embassy
# embassy
# embassy
# embassy
# embassy
# embassy
# police
# restaurant
# school
# cinema
# school
# atm
# parking
# post_box
# cinema
# atm
# hospital
# pharmacy
# bar
# restaurant
# bank
# parking
# school
# place_of_worship
# restaurant
# marketplace
# cafe
# post_office
# car_rental
# bank
# atm
# atm
# pharmacy
# bank
# doctors
# bank
# fast_food
# place_of_worship
# place_of_worship
# cinema
# school
# atm
# fuel
# atm
# bank
# school
# cinema
# restaurant
# Jhandu Mansions
# Garden Isles Tower
# Kasa Isles 03
# Tower 14
# Tower 23
# Mathura Road
# Krishna Temple
# Videocon Tower
# Delhi Metro Magenta Line
# Delhi Metro Magenta Line
# NCC Building
# Windsor Court
# Agricultural Sciences Recruitment Board
# Division of Seed Technology
# B Block Park Jogging & Walking Track
# Mandi House Chowk
# Engineer's Estate
# Indra Prasth Marg
# Doctor Rajendra Prasad Road
# Raisina Road
# school of planning and architecure, new delhi
# Bombay Mart
# NH24 Bypass
# Internal road
# Pedestrian foot path
# Delhi Metro Magenta Line
# Adult Swimming Pool
# Sector 69
# bhumiya temple
# Chitragupta Road
# Ajmeri Gate Bridge
# St Stephens Hospital
# Flyash Pond
# Yamuna Expressway
# Fulwari Park
# Sector 11 Park
# Shamshi park
# Malibu Town Central Park
# Mother Teresa School Park
# Vasundhara Post Office
# B4
# Kosmos 04
# Kosmos 16
# Kosmos 29
# Kosmos 44
# Kosmos 56
# Kosmos 67
# Kosmos 75
# Block F
# Block P
# Panchsheel Balak Inter College
# Kasa Isles xx
# Josip Broz Tito Marg
# Wazirabad Road
# Preet Vihar Park 2
# Park
# School of Physical Sciences
# Convention Centre
# RK Convent School
# RK Convent
# Mehrauli Gurgaon Road
# parking
# Palika Parking
# NetEdge Garden
# NDM1
# Arya Model Garden
# Shivaji Road
# DSUI Swimming Pool
# HUDA Community Centre
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Eastern Peripheral Expressway
# Dwarka Road
# Gali Number
# F Mohan Senapati Marg
# Hindon Elevated Road
# Kilash Colony Park
# Jagdamba camp

# %%
# checking for node_ref
for keys in nodes_lst:
    if "node_ref" in keys.keys():
        print(keys["node_ref"])
        break
# Out:
# ['245765418', '2753154964', '2769850480']

# %%
# functions that deal with post codes
invalid_pins = []
def pin_validator(pin):
    """
    Return a pin if pin code is 6 digit valid pin. Else append invalid pin codes to a list.
    """
    pin_validator = re.compile(r'^[1-9][0-9]{5}$') 
    match = pin_validator.search(pin)
    if match:
        correct_pin = pin

        return correct_pin
    
    invalid_pins.append(pin)
    #return pin

def simple_pin_code_fix(pin_code):
    """
    Return a corrected pin code if a wrong pin code is found. Else return just the pin code.
    This is not a generalized solution. It fixes only the wrong pin codes of this dataset.
    """
    pin = list(pin_code)
    
    if len(pin) > 6 and pin_code.count("0") > 3:
        pin.remove("0")
        correct_pin = "".join(pin)

        return correct_pin

    elif len(pin) > 6 and pin_code.count(" ") > 0:
        pin.remove(" ")
        correct_pin = "".join(pin)

        return correct_pin

    elif pin_code.startswith("10", 0, 2):
        correct_pin = re.sub(r"^10", "11", pin_code)

        return correct_pin
    
    elif pin_code.endswith("0", -1) and pin_code.startswith("2", 0) and len(pin) > 6:
        del pin[-1]
        correct_pin = "".join(pin)
        
        return correct_pin
    
    return pin_code

def is_pin_code(elem):
    """Return True if the value of two operands are equal. Return False otherwise."""
    return elem.attrib["k"] == "addr:postcode"

# %%
# first pass at correcting pin codes
invalid_pin_list = []
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "tag":
        if elem.attrib["k"] == "addr:postcode":
            pin = pin_validator(simple_postal_code_fix(elem.attrib["v"])) # check for 6 digit pin code
            if pin.startswith("Invalid pin code:"):
                invalid_pin_list.append(pin)
            else:
                print(pin)

print()
print(invalid_pin_list)
# One invalid entry
# I'll make a second pass at fixing this.
# Out:
# 122001
# 110011
# 110070
# 122002
# 122018
# 122018
# 122018
# 122001
# 110006
# 110006
# 110006
# 110006
# 110006
# 110006
# 122001
# 122001
# 122001
# 122001
# 122001
# 122001
# 122001
# 110007
# 201307
# 110001
# 122018
# 110085
# 110043
# 110055
# 110074
# 110091
# 110029
# 110042
# 110042
# 110002
# 201301
# 110092
# 122002
# 110077
# 201014
# 110092
# 201308
# 110016
# 250101
# 110017
# 110021
# 110009
# 110044
# 110001
# 122413
# 110055
# 110024
# 110092
# 110092
# 110092
# 110092
# 110053
# 201301
# 110032
# 201014
# 110016
# 110070
# 110001
# 110075
# 121004
# 201001
# 122011
# 110001
# 110070
# 201301
# 110002
# 110075
# 110058
# 110052
# 110008
# 110044
# 201002
# 110096
# 110075
# 110075
# 110075
# 110096
# 201001
# 110091
# 110085
# 110042
# 110085
# 110085
# 201301
# 110067
# 110070
# 122001
# 110006
# 110057
# 122011
# 110029
# 122001
# 201306
# 201301
# 110096
# 201314
# 110025
# 110034
# 122102
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110063
# 124507
# 124507
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110087
# 110092
# 110085
# 110088
# 110088
# 201012
# 110085
# 122011
# 110096
# 121004
#
# ['Invalid pin code: 2013010']

# %%
# Now that I know how many unexpected street names are there in the data I can 
# prepare a better data structure to contain them.
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE) # regex that looks for the last word in a line

# creating a list of expected street names
expected = ['Delhi', 'Street', 'Nagar', 'Sadan', 'Marg', 'Road', 'Avenue', 'Circle', 'Mayur'
            'Place', 'Sector', 'Vihar', 'Enclave', 'Block', 'Chowk', 'Colony', 'Mandir', 'Market', 'Place', 'Lane',
            'Estate', 'Bazaar', 'Kunj', 'Circus', 'Extension', 'College']

# creating a dictionary to map problematic names with corrected names
mapping = {"delhi" : "Delhi",
           "road" : "Road",
           "block" : "Block",
           "sector": "Sector",
           "nagar" : "Nagar",
           "NAGAR" : "Nagar",
           "sadan" : "Sadan",
           "marg" : "Marg",
           "ave" : "Avenue",
           "ave." : "Avenue",
           "vihar" : "Vihar",
           "place" : "Place",
           "colony" : "Colony",
           "chowk" : "Chowk",
           "circle" : "Circle",
           "VIJAY" : "Vijay",
           "II" : "2",
           "mayor" : "Mayur",
           "–" : "",
           "north" : "North",
           "flat" : "Flat",
          "janakpuri" : "Janakpuri",
          "footpath" : "Footpath",
          "GK" : "Greater Kailash",
          "-" : " ",
          "bazar" : "Bazar",
          "Pahargan" : "Paharganj"}

counter = 0 # counter to check total number of street names
street_dict = defaultdict(set) # container for the unexpected values

for event, elem in ET.iterparse(bigger_sample_file, events=("start", )):
    if elem.tag == "node" or elem.tag == "way":
        
        for tag in elem.iter("tag"):
            if tag.attrib["k"] == "addr:street":
                counter += 1 # counter increments if street name is found
                match = street_type_re.search(tag.attrib["v"]) # Last name of street names
                # are referenced to a variable match
                if match: # if a pattern matches successfully
                    street_name = match.group() # group the matched patterns
                    if street_name not in expected: # if the group matches expected street names
                        street_dict[street_name].add(tag.attrib["v"]) # append them

pprint(dict(street_dict))
print()
print("{:.2f}% {}".format((len(dict(street_dict))/counter)*100, "Unexpected street names the sample dataset"))
print()
# To actually correct the unexpected street names
# I'll iterate over the key and values of the street_dict by calling the .item() method on it.
for k, v in street_dict.items():
    for name in v: # As v contain a set. I'll iterate over the items in the set.  
        for key in mapping.keys(): # I'll also iterate over the keys of the mapping dict
            match = re.search(key, name) # and then search for a pattern between the name and keys
            if match: # if a match is found 
                print("Match Found:", name, "*", match.group())
                change_name = re.sub(key, mapping[key], name) # I'll sub. the bad names with the good ones in mapping dict
                print("Correction:", name, "-->", change_name.title(),"\n")
# Out:
# {'17C': {'Sector 17C'},
#  '2': {'South City 2'},
#  '210': {'Road 210'},
#  '3': {'Gharoli Road, Mayur Vihar Phase - 3'},
#  '4': {'DLF Phase 4'},
#  '44': {'Sector 44'},
#  '46': {'Sector 46'},
#  '56': {'Sector 56'},
#  '6': {'Sector 6'},
#  'A': {'Block A'},
#  'A-6': {'A-6'},
#  'A1': {'Block A1'},
#  'B': {'Block B'},
#  'Delhi-110089': {'G-5, Sector-16, Rohini, New Delhi-110089'},
#  'Flats': {'Street E, Munirka DDA Flats'},
#  'Gurgaon': {'Bilaspur Khurd, Gurgaon'},
#  'Harola': {'Hanuman Market Harola'},
#  'II': {'South City II'},
#  'Janakpuri': {'C Block, Janakpuri'},
#  'NIT': {'NIT'},
#  'No.1': {'Block No.1'},
#  'No.10': {'Block No.10'},
#  'No.11': {'Block No.11'},
#  'No.12': {'Block No.12'},
#  'No.13': {'Block No.13'},
#  'No.14': {'Block No.14'},
#  'No.2': {'Block No.2'},
#  'No.3': {'Street No.3', 'Block No.3'},
#  'No.5': {'Block No.5'},
#  'No.6': {'Block No.6'},
#  'No.7': {'Block No.7'},
#  'No.8': {'Block No.8'},
#  'No.9': {'Block No.9'},
#  'Noida,': {'C - 99, Sector - 4, Sector 4 Noida, Block C, Sector 4, Noida,'},
#  'Okhla': {'Near Hari Masjid, Jogabai Extn, Okhla'},
#  'Pahargan': {'Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat '
#               'Nagar, Pahargan'},
#  'Paharganj': {'Chuna Mandi, Paharganj'},
#  'Part-A': {'Modern Industrial Estate Part-A'},
#  'Phi-02': {'Phi-02'},
#  'Pitampura': {'Vardhman Times Plaza, Plot 13, DDA Community Centre, Road 44, '
#                'Pitampura'},
#  'Rohini': {'Sector-3, Rohini'},
#  'S1': {'S1'},
#  'Sector-18': {'Sector-18'},
#  'Sector-21A': {'Sector-21A'},
#  'Sector-56': {'Sector-56'},
#  'U-12': {'U-12'},
#  'UP': {'Block G, Patel Nagar 3, Ghaziabad 201001, UP'},
#  'University': {'Jawaharlal Nehru University'},
#  'Vasundhara': {'Sector 17, Vasundhara'},
#  'delhi': {'delhi'},
#  'gate': {'lothian road, Kashmere gate'},
#  'iTechPark': {'649-6th Floor, Tower A Spaze iTechPark'},
#  'janakpuri': {'janakpuri'},
#  'marg': {'suchitra kriplani marg'},
#  'nagar': {'shastri nagar'},
#  'ph-1': {'Shiv Arcade,aacharya niketan,mayor vihar ph-1'},
#  'road': {'palika bazar road'}}
#
# 30.16% Unexpected street names the sample dataset
#
# Match Found: South City II * II
# Correction: South City II --> South City 2
#
# Match Found: janakpuri * janakpuri
# Correction: janakpuri --> Janakpuri
#
# Match Found: 649-6th Floor, Tower A Spaze iTechPark * -
# Correction: 649-6th Floor, Tower A Spaze iTechPark --> 649 6Th Floor, Tower A Spaze Itechpark
#
# Match Found: palika bazar road * road
# Correction: palika bazar road --> Palika Bazar Road
#
# Match Found: palika bazar road * bazar
# Correction: palika bazar road --> Palika Bazar Road
#
# Match Found: shastri nagar * nagar
# Correction: shastri nagar --> Shastri Nagar
#
# Match Found: delhi * delhi
# Correction: delhi --> Delhi
#
# Match Found: Chuna Mandi, Paharganj * Pahargan
# Correction: Chuna Mandi, Paharganj --> Chuna Mandi, Pahargangj
#
# Match Found: Shiv Arcade,aacharya niketan,mayor vihar ph-1 * vihar
# Correction: Shiv Arcade,aacharya niketan,mayor vihar ph-1 --> Shiv Arcade,Aacharya Niketan,Mayor Vihar Ph-1
#
# Match Found: Shiv Arcade,aacharya niketan,mayor vihar ph-1 * mayor
# Correction: Shiv Arcade,aacharya niketan,mayor vihar ph-1 --> Shiv Arcade,Aacharya Niketan,Mayur Vihar Ph-1
#
# Match Found: Shiv Arcade,aacharya niketan,mayor vihar ph-1 * -
# Correction: Shiv Arcade,aacharya niketan,mayor vihar ph-1 --> Shiv Arcade,Aacharya Niketan,Mayor Vihar Ph 1
#
# Match Found: Phi-02 * -
# Correction: Phi-02 --> Phi 02
#
# Match Found: G-5, Sector-16, Rohini, New Delhi-110089 * -
# Correction: G-5, Sector-16, Rohini, New Delhi-110089 --> G 5, Sector 16, Rohini, New Delhi 110089
#
# Match Found: Sector-18 * -
# Correction: Sector-18 --> Sector 18
#
# Match Found: Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat Nagar, Pahargan * Pahargan
# Correction: Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat Nagar, Pahargan --> Shop No. 22/1, Krishna Market, Main Bazar, Pahar Ganj, Bharat Nagar, Pahargang
#
# Match Found: C - 99, Sector - 4, Sector 4 Noida, Block C, Sector 4, Noida, * -
# Correction: C - 99, Sector - 4, Sector 4 Noida, Block C, Sector 4, Noida, --> C   99, Sector   4, Sector 4 Noida, Block C, Sector 4, Noida,
#
# Match Found: suchitra kriplani marg * marg
# Correction: suchitra kriplani marg --> Suchitra Kriplani Marg
#
# Match Found: Gharoli Road, Mayur Vihar Phase - 3 * -
# Correction: Gharoli Road, Mayur Vihar Phase - 3 --> Gharoli Road, Mayur Vihar Phase   3
#
# Match Found: U-12 * -
# Correction: U-12 --> U 12
#
# Match Found: lothian road, Kashmere gate * road
# Correction: lothian road, Kashmere gate --> Lothian Road, Kashmere Gate
#
# Match Found: Sector-56 * -
# Correction: Sector-56 --> Sector 56
#
# Match Found: Sector-21A * -
# Correction: Sector-21A --> Sector 21A
#
# Match Found: A-6 * -
# Correction: A-6 --> A 6
#
# Match Found: Modern Industrial Estate Part-A * -
# Correction: Modern Industrial Estate Part-A --> Modern Industrial Estate Part A
#
# Match Found: Sector-3, Rohini * -
# Correction: Sector-3, Rohini --> Sector 3, Rohini

# %%
# funtions that deal with street names
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

def update_street_name(name, mapping):
    """
    Return correct name if name is found in mapping dictionary. 
    Return name otherwise.
    """
    for key in mapping.keys():
        match = re.search(key, name) 
        if match:
            correct_name = re.sub(key, mapping[key], name)
            
            return correct_name.title()
        
    return name
                
def audit_street_type(street_name):
    """
    Return updated street name if name is not in expected street name list. 
    Return street name otherwise.
    """
    match = street_type_re.search(street_name)
    if match:
        street_type = match.group()
        if street_type not in expected:
            return update_street_name(street_name, mapping)
    
    return street_name

def is_street_name(elem):
    """Return True if the value of two operands are equal. Return False otherwise."""
    return elem.attrib['k'] == "addr:street"

# %%
# phone number with problems
for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if "phone" in tag.attrib["k"]:
                print("yes:", tag.attrib["k"], tag.attrib["v"])
# Out:
# yes: phone +91 11 3955 5000
# yes: phone 91-11-2687-6564
# yes: phone +91-120-3830000; +91-11-23582812 / 4658
# yes: phone +911126801804
# yes: phone +91 11 3218206
# yes: phone 9990291418
# yes: phone 08527450737
# yes: phone +91 9958080618
# yes: phone +918130770731
# yes: phone 9910536692
# yes: phone 911146082303
# yes: phone 08287872020
# yes: phone +911141677410
# yes: phone +91 11 4995 9500
# yes: phone +91 9172313994
# yes: phone +911140047000
# yes: phone +919911119039
# yes: phone 0120 252 0242
# yes: phone 8586986389
# yes: phone +91 11 4309 0000
# yes: phone +91 95407 59909

# %%
# functions to fix phone numbers
def is_phone_number(elem):
    """
    Return True if the value of the operands are equal. Return False otherwise.
    """
    return elem.attrib["k"] == "phone"

def phone_fixer(phone):
    """
    Return a phone number after striping its whitespaces or non-digit characters except "+" (plus symbol). 
    """
    phone_num = phone
    join_num = "".join(phone_num.strip().split())
    match_num = re.search(r"[^\d+]", join_num)
    if match_num:
        fix_num = re.sub(match_num.group(), "", join_num)
        
        return fix_num
    
    return join_num

# %%
# code with all the pieces together. This code should now clean the street names, pin codes and phone numbers.
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ['Delhi', 'Street', 'Nagar', 'Sadan', 'Marg', 'Road', 'Avenue', 'Circle', 'Mayur'
            'Place', 'Sector', 'Vihar', 'Enclave', 'Block', 'Chowk', 'Colony', 'Mandir', 'Market', 'Place', 'Lane',
            'Estate', 'Bazaar', 'Kunj', 'Circus', 'Extension', 'College', "Paharganj", "Janakpuri", "Flat", "Palika", 
            'Gate']

CREATED = ["version", "changeset", "timestamp", "user", "uid"] # list of expected tags

mapping = {"delhi" : "Delhi",
           "road" : "Road",
           "block" : "Block",
           "sector": "Sector",
           "nagar" : "Nagar",
           "NAGAR" : "Nagar",
           "sadan" : "Sadan",
           "marg" : "Marg",
           "ave" : "Avenue",
           "ave." : "Avenue",
           "vihar" : "Vihar",
           "place" : "Place",
           "colony" : "Colony",
           "chowk" : "Chowk",
           "circle" : "Circle",
           "VIJAY" : "Vijay",
           "II" : "2",
           "–" : "",
           "north" : "North",
           "flat" : "Flat",
          "janakpuri" : "Janakpuri",
          "footpath" : "Footpath",
          "GK" : "Greater Kailash",
          "-" : " ",
          "bazar" : "Bazar",
          "Pahargan" : "Paharganj",}

street_dict = defaultdict(set)

nodes_lst = [] # This list will append updated dictionary

for event, elem in ET.iterparse(bigger_sample_file):
    if elem.tag == "node" or elem.tag == "way":
        nodes = {"created": {}, "type" : elem.tag} # dictionary that will store attributes and their values
        if "lat" and "lon" in elem.attrib:
                nodes["pos"] = [float(elem.attrib["lat"]), float(elem.attrib["lon"])]
        
        for tag in elem.attrib:
            if tag == "lat" or tag == "lon":
                continue
            elif tag in CREATED:
                nodes["created"][tag] = elem.attrib[tag]
            else:
                nodes[tag] = elem.attrib[tag]
        
        for data in elem.iter("tag"):
            match = problemchars.search(data.attrib["k"])
            if match:
                continue
            elif data.attrib["k"].startswith("addr:"):
                address = data.attrib["k"].split(":", 2)  
                if len(address) == 2:
                    if "address" not in nodes:
                        nodes["address"] = {}
                    elif is_street_name(data):
                        nodes["address"][address[1]] = audit_street_type(data.attrib["v"])
                    elif is_pin_code(data):
                        nodes["address"][address[1]] = pin_validator(simple_pin_code_fix(data.attrib["v"]))
            else:
                if is_phone_number(data):
                    nodes[data.attrib["k"]] = phone_fixer(data.attrib["v"])
                else:
                    nodes[data.attrib["k"]] = data.attrib["v"]
        
        node_ref = []        
        for nd_tag in elem.iter("nd"):
            node_ref.append(nd_tag.attrib["ref"])
        
        if len(node_ref) > 0:
            nodes["node_ref"] = node_ref
        
        nodes_lst.append(nodes)

# %%
# total number of entries
len(nodes_lst)
# Out:
# 410188

# %%
# fixed phone numbers
for key in nodes_lst:
    if "phone" in key.keys():
        print(key["phone"])
# Out:
# +911139555000
# 911126876564
# +911203830000;+911123582812/4658
# +911126801804
# +91113218206
# 9990291418
# 08527450737
# +919958080618
# +918130770731
# 9910536692
# 911146082303
# 08287872020
# +911141677410
# +911149959500
# +919172313994
# +911140047000
# +919911119039
# 01202520242
# 8586986389
# +911143090000
# +919540759909

# %%
# fixed street names and postal address
for key in nodes_lst:
    if "address" in key.keys():
        for k, v in key["address"].items():
            print(k, v)
            break
# Out:
# street Old Delhi Gurgaon Road
# street Aurangzeb Road
# street Bhavani Kunj, Vasant Kunj
# street Sector 46
# postcode 122002
# street South City 2
# street South City 2
# street South City 2
# street Sector 17C
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
# street Sector 46
#